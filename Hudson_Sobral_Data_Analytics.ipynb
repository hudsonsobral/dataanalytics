# %% [markdown]
# <a href="https://colab.research.google.com/github/hudsonsobral/dataanalytics/blob/main/Hudson_Sobral_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <style>
#         body { font-family: Arial, sans-serif; line-height: 1.6; color: #333; }
#         .section-title { color: #2c5aa0; }
#         .name { color: #1e4d72; font-weight: bold; }
#         .contact-info { color: #666; }
#         .skill-category { color: #2c5aa0; }
#         .skill-item { color: #444; }
#         .highlight { color: #d63384; font-weight: bold; }
#     </style>
# </head>
# <body>
#
# <h1 class="section-title">📋 1. Dados Pessoais</h1>
#
# <p><strong class="name">👤 Nome:</strong> Hudson Sobral de Faria</p>
# <p><strong>📧 Email:</strong> <a href="mailto:hudsonsobral@gmail.com" class="contact-info">hudsonsobral@gmail.com</a></p>
# <p><strong>💼 LinkedIn:</strong> <a href="https://www.linkedin.com/in/hudson-sobral-de-faria-a6baa143/" class="contact-info">linkedin.com/in/hudson-sobral-de-faria-a6baa143/</a></p>
# <p><strong>📱 Instagram:</strong> <a href="https://www.instagram.com/hudsonsobralf" class="contact-info">@hudsonsobralf</a></p>
#
# <hr>
#
# <h1 class="section-title">🎯 2. Objetivo</h1>
#
# <p>Meu objetivo principal está em compreender melhor todo o cenário de Data Analytics, entender como posso aplicar no meu dia a dia, principalmente a cerca de análise de dados estruturados, como relatórios a serem retirados do meu ERP, para construção de <span class="highlight">Dashboards e KPIs</span> para diretoria.</p>
#
# <hr>
#
# <h1 class="section-title">🛠️ 3. Habilidades (Hard e Soft Skills)</h1>
#
# <h2 class="skill-category">💻 3.1 Hard Skills</h2>
# <ul>
# <li class="skill-item"><strong>⚙️ Gestão de Tecnologia:</strong> Experiência prática com todas ferramentas apresentadas no curso.</li>
# <li class="skill-item"><strong>🗃️ SQL:</strong> Habilidade para extrair, manipular e analisar dados em bancos de dados relacionais.</li>
# <li class="skill-item"><strong>📊 Power BI:</strong> Criação de dashboards interativos e relatórios analíticos para insights de negócios.</li>
# <li class="skill-item"><strong>🐍 Python:</strong> Básico conhecimento em programação para análise de dados e automação de tarefas.</li>
# </ul>
#
# <h2 class="skill-category">🧠 3.2 Soft Skills</h2>
# <ul>
# <li class="skill-item"><strong>📈 Experiência de mercado:</strong> Trabalho com tecnologia a mais de 17 anos, muitos dele focados em infraestrutura, redes e sistemas</li>
# <li class="skill-item"><strong>🤝 Trabalho em Equipe:</strong> Colaboração com equipes multidisciplinares para alcançar objetivos comuns.</li>
# <li class="skill-item"><strong>🧩 Pensamento Crítico:</strong> Análise de problemas de forma lógica e objetiva, buscando soluções eficientes.</li>
# <li class="skill-item"><strong>⏰ Gestão de Tempo:</strong> Capacidade de organizar e priorizar tarefas, garantindo entregas dentro dos prazos estipulados.</li>
# </ul>
#
# <hr>
#
# <h1 class="section-title">📝 4. Breve Descrição sobre minhas Skills</h1>
#
# <p>Tenho uma trajetória foi construída com dedicação e aprendizado em cada etapa, começando como estagiário e passando por cargos como técnico, analista, coordenador, até alcançar posições de gestão. Sou formado em <span class="highlight">Tecnologia de Redes de Computadores pelo SENAI FATESG</span> e pós-graduado com <span class="highlight">MBA em Tecnologia, Governança e Transformação Digital pelo IPOG</span>.</p>
#
# <p>Minha filosofia de trabalho é integrar a tecnologia em todas as etapas do negócio, abrangendo desde infraestrutura - vasta experiência em sustentação de ambientes <span class="highlight">cloud, locais (OnPremise) ou Híbridos</span> - e suporte até gestão, segurança e inovação. Acredito que a implementação de compliance, governança, mapeamento de processos e camadas robustas de segurança da informação são pilares essenciais para o crescimento sustentável de uma empresa, impactando tanto o faturamento quanto o desenvolvimento dos profissionais.</p>
#
# <p>Tenho experiência em diversos segmentos, incluindo <span class="highlight">comércio, agronegócio, indústria e construção civil</span>, onde atuei em implantações de sistemas e trabalhei com ERPs renomados como <span class="highlight">Sênior (UAU), TOTVS e Sienge</span>. Essa diversidade me permite entender as particularidades de cada setor e propor soluções tecnológicas que impulsionam a competitividade.</p>
#
# </body>
# </html>

# %% [markdown]
# # 5. Introdução ao Pyton

# %%
print ("hello world")
# Out:
# hello world

# %%
print ("Hudson Sobral de Faria")
# Out:
# Hudson Sobral de Faria

# %%
print (10 / 5)
# Out:
# 2.0

# %%
import sys
print (sys.version)
# Out:
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=12, micro=11, releaselevel='final', serial=0)

# %%
import pandas as pd

# %%
10 + 10
# Out:
# 20

# %%
20-5
# Out:
# 15

# %%
20 / 5
# Out:
# 4.0

# %%
20 * 2
# Out:
# 40

# %%
nome = input("Digite seu nome: ")
print ("Olá", nome)
# Out:
# Digite seu nome: Hudson
# Olá Hudson

# %%
a = "Hudson"
print (type(a))
# Out:
# <class 'str'>

# %%
b = 20
print (type(b))
# Out:
# <class 'int'>

# %%
c = 10.9
print (type(c))
# Out:
# <class 'float'>

# %%
a = 20
b = 30
c = 80
soma = a + b + c
print (soma)
# Out:
# 130

# %%
nome = "Hudson "
sobrenome = "Sobral"
print(nome + sobrenome)
# Out:
# Hudson Sobral

# %%
# Exemplo de Tomada de Decisão
idade = 18
if idade >= 18:
    print("Você é maior de idade.")
else:
    print("Você é menor de idade.")
# Out:
# Você é maior de idade.

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # 6. Hobbies e Lazer
#
# * Tempo com família e filhos, sou casado e pai de 3 filhos, portanto estes momentos pra mim são primordiais e inegociáveis.
# * Atividades físicas como academia diáriamente e futebol com os amigos.
# * Gostar bastante de futebol, sou Corinthiano fervoroso e acompanho bastante meu time assistindo aos jogos.

# %% [markdown]
# # 7. Estratégia
#
# - Conceitos de Data Warehouse/Big Data
# - Desenvolvimento e Tratamento de Dados em Massa
# - Mineração de dados para tomadas de decisão
# - Análise de dados para tomada de decisão - BPM -  para atingir os reais objetivos.

# %% [markdown]
# # 8. Estatística

# %%
a = [1, 2, 3]
media = sum(a) / len(a)
print (media)
# Out:
# 2.0

# %% [markdown]
# # 9. Pandas
#
# O Pandas é usado em todo fluxo de trabalho para análise de dados. Com os pandas você pode: importar conjuntos de dados de bancos de dados, planilhas , arquivos de valores separados por vírgula (CSV)

# %%
import pandas as pd
df = pd.read_csv('/TitanicDados.txt')

# %%
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_nome_pass = df[['Name','Age']]
print(titanic_nome_pass)
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                                Heikkinen, Miss Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                        Graham, Miss Margaret Edith  19.0
# 888            Johnston, Miss Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
len(df)
# Out:
# 891

# %%
len(df.columns)
# Out:
# 12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
smallTitanic = df.head(10)[["Name","Age"]]
print(smallTitanic)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0
# 5                                   Moran, Mr. James   NaN
# 6                            McCarthy, Mr. Timothy J  54.0
# 7                      Palsson, Master Gosta Leonard   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
smallTitanicFiltered = df[df["Age"] > 30]
print(smallTitanicFiltered)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                             Bonnell, Miss Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
drescricao = df.describe()
print(drescricao)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df = df.rename(columns={'Age': 'Idade', 'Name': 'Nome'})
display(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Nome     Sex  Idade  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                              Heikkinen, Miss Laina  female   26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                           Allen, Mr. William Henry    male   35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dados1 = {
 'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
 'Preço': [50, 100, 150, None],
  'Quantidade': [100, 150, 300, None]
}

# %%
print(dados1)
# Out:
# {'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'], 'Preço': [50, 100, 150, None], 'Quantidade': [100, 150, 300, None]}

# %%
df1 = pd.DataFrame(dados1)
# Exibindo o DataFrame
print(df1)
print()
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis    NaN         NaN

# %%
# Substituir valores ausentes por quinhentos
df1.fillna(500, inplace=True)
print(df1)
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta   50.0       100.0
# 1     Calça  100.0       150.0
# 2   Jaqueta  150.0       300.0
# 3     Tênis  500.0       500.0

# %%
# agrupamento horizontal
import pandas as pd
# DataFrame 1: Produtos
produtos = {
 'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
 'Preço': [50, 100, 200, 150]
}
df_produtos = pd.DataFrame(produtos)
# DataFrame 2: Vendas
vendas = {
 'Quantidade': [100, 150, 80, 120]
}
df_vendas = pd.DataFrame(vendas)
# Agrupar horizontalmente (adicionar as colunas de df_vendas ao df_produtos)
df_completo = pd.concat([df_produtos, df_vendas], axis=1)
# Exibir o DataFrame resultante
print(df_completo)
# Out:
#     Produto  Preço  Quantidade
# 0  Camiseta     50         100
# 1     Calça    100         150
# 2   Jaqueta    200          80
# 3     Tênis    150         120

# %%
# agrupamento horizontal
import pandas as pd
# DataFrame 1: Produtos
produtos = {
 'Produto': ['Camiseta', 'Calça', 'Jaqueta', 'Tênis'],
 'Preço': [50, 100, 200, 150]
}
df_produtos = pd.DataFrame(produtos)
# DataFrame 2: Vendas
vendas = {
 'Quantidade': [100, 150, 80, 120]
}
grade = {
 'Notas': ["A", "B", "C", "D"]
}
df_vendas = pd.DataFrame(vendas)
df_grade = pd.DataFrame(grade)
df_vendas = pd.DataFrame(vendas)
# Agrupar horizontalmente (adicionar as colunas de df_vendas ao df_produtos)
df_completo = pd.concat([df_produtos, df_vendas, df_grade], axis=1)
# Calcular o Preço Total
df_completo['Preço Total'] = df_completo['Preço'] * df_completo['Quantidade']
# Exibir o DataFrame resultante
print(df_completo)
# Out:
#     Produto  Preço  Quantidade Notas  Preço Total
# 0  Camiseta     50         100     A         5000
# 1     Calça    100         150     B        15000
# 2   Jaqueta    200          80     C        16000
# 3     Tênis    150         120     D        18000

# %% [markdown]
# # 10. Estatística

# %%
# Cálculo da Média
import numpy as np

# Exemplo com os números: 2, 4, 6, 8, 10
numeros = [2, 4, 6, 8, 10]

# Método 1: Usando função built-in
media1 = sum(numeros) / len(numeros)

# Método 2: Usando numpy
media2 = np.mean(numeros)

# Método 3: Implementando a fórmula manualmente
def calcular_media(valores):
    return sum(valores) / len(valores)

media3 = calcular_media(numeros)

print(f"Números: {numeros}")
print(f"Média (método 1): {media1}")
print(f"Média (método 2): {media2}")
print(f"Média (método 3): {media3}")
# Out:
# Números: [2, 4, 6, 8, 10]
# Média (método 1): 6.0
# Média (método 2): 6.0
# Média (método 3): 6.0

# %%
# Média
a = [2, 4, 6, 8, 10]
print(f'Média: {sum(a) / len(a)}')
# Out:
# Média: 6.0

# %%
import statistics as st
print(f'Média: {st.mean(a)}')
# Out:
# Média: 6

# %%
# número ímpar de elementos
b = [1500, 1800, 2000, 2100, 2200, 2400]
print(f'Mediana: {sorted(b)[len(b) // 2] if len(b) % 2 != 0 else (sorted(b)[len(b) // 2 - 1] + sorted(b)[len(b) // 2]) / 2}')
# Out:
# Mediana: 2050.0

# %%
import numpy as np
import pandas as pd
from statistics import mode
notas = [8, 7, 6, 9, 7, 8, 10, 9, 6, 7, 8, 2, 10, 9, 7, 6, 8, 9, 5, 10]
media = np.mean(notas)
mediana = np.median(notas)
moda = mode(notas)
print("Média   :", media)
print("Mediana :", mediana)
print("Moda    :", moda)
# Out:
# Média   : 7.55
# Mediana : 8.0
# Moda    : 8

# %%
amplitude = max(notas) - min(notas)
variancia = np.var(notas, ddof=1) # ddof=1 → amostral
desvio_padrao = np.std(notas, ddof=1)
cv = desvio_padrao / media
print("Amplitude        :", amplitude)
print("Variância        :", variancia)
print("Desvio Padrão    :", desvio_padrao)
print("Coef. Variação   :", cv)
# Out:
# Amplitude        : 8
# Variância        : 3.8394736842105264
# Desvio Padrão    : 1.9594574974238472
# Coef. Variação   : 0.2595307943607745

# %% [markdown]
# # 11. Visualização

# %%
notas = [8, 7, 6, 9, 7, 8, 10, 9, 6, 7, 8, 2, 10, 9, 7, 6, 8, 9, 5, 10]

# %%
import matplotlib.pyplot as plt
plt.hist(notas, bins=10, edgecolor="black")
plt.title("Histograma de Notas")
plt.xlabel("Notas")
plt.ylabel("Quantidade")
# Salva a imagem (antes do show)
plt.savefig("/media/histograma_notas.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# Salva a imagem (antes do show)
plt.savefig("histograma_notas.png", dpi=300, bbox_inches="tight")

# %%
import pandas as pd
df = pd.DataFrame({"Notas": notas})
contagem = df["Notas"].value_counts().sort_index()
contagem.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Frequência das Notas")
plt.xlabel("Nota")
plt.ylabel("Quantidade")
# Salva a imagem (antes do show)
plt.savefig("/media/barras_notas.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({"Notas": notas})
contagem = df["Notas"].value_counts().sort_index()
contagem.plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Frequência das Notas")
plt.xlabel("Nota")
plt.ylabel("Quantidade")
# Salva a imagem (antes do show)
#plt.savefig("../img/barras_notas.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
contagem.plot(kind="pie", autopct="%1.1f%%", figsize=(6,6))
plt.title("Proporção de cada Nota")
plt.ylabel("")  # remove label lateral
#plt.savefig("../img/pizza_notas.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # 12. Análise de Caso Real ( Tópico Livre )

# %%
import pandas as pd
df = pd.read_csv('/issues.txt', sep=';')

# %%
df.head(50)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#       #            Tipo Prioridade  \
# 0   760         Suporte     Normal
# 1   755         Suporte     Normal
# 2   746         Suporte     Normal
# 3   739         Suporte     Normal
# 4   730         Suporte     Normal
# 5   725         Suporte     Normal
# 6   702         Suporte     Normal
# 7   701         Suporte     Normal
# 8   700         Suporte     Normal
# 9   699         Suporte     Normal
# 10  696         Suporte     Normal
# 11  695         Suporte     Normal
# 12  691  Infraestrutura     Normal
# 13  668  Infraestrutura     Normal
# 14  667  Infraestrutura     Normal
# 15  666  Infraestrutura     Normal
# 16  665         Suporte     Normal
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ler o arquivo CSV com separador ';'
df = pd.read_csv('/issues.txt', sep=';')

# Verificar as primeiras linhas e colunas
print("Primeiras 5 linhas do dataset:")
print(df.head())
print("\nColunas disponíveis:")
print(df.columns.tolist())
print("\nShape do dataset:", df.shape)

# Contar solicitações por departamento
departamentos_count = df['Departamento/Filial'].value_counts()
print("\nContagem por departamento:")
print(departamentos_count)

# Criar gráfico de pizza
plt.figure(figsize=(12, 8))
colors = plt.cm.Set3(range(len(departamentos_count)))

# Criar o gráfico de pizza
wedges, texts, autotexts = plt.pie(departamentos_count.values,
                                   labels=departamentos_count.index,
                                   autopct='%1.1f%%',
                                   startangle=90,
                                   colors=colors)

# Melhorar a aparência do texto
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontweight('bold')
    autotext.set_fontsize(10)

for text in texts:
    text.set_fontsize(10)

plt.title('Distribuição de Solicitações por Departamento', fontsize=16, fontweight='bold', pad=20)
plt.axis('equal')  # Para garantir que o gráfico seja circular

# Adicionar uma legenda
plt.legend(wedges, [f'{dept}: {count} solicitações' for dept, count in zip(departamentos_count.index, departamentos_count.values)],
          title="Departamentos",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.tight_layout()
plt.show()

# Mostrar estatísticas resumidas
print(f"\nTotal de solicitações: {len(df)}")
print(f"Número de departamentos: {len(departamentos_count)}")
print(f"Departamento com mais solicitações: {departamentos_count.index[0]} ({departamentos_count.iloc[0]} solicitações)")
# Out:
# Primeiras 5 linhas do dataset:
#      #     Tipo Prioridade                              Assunto  \
# 0  760  Suporte     Normal                   Alterdata não abre
# 1  755  Suporte     Normal  Desbloqueio de Software - Navegador
# 2  746  Suporte     Normal                        Site não abre
# 3  739  Suporte     Normal       Permissão de acesso ao sistema
# 4  730  Suporte     Normal               Instalação de Software
#
#            Alterado Usuário/Colaborador Departamento/Filial Data de início  \
# 0  12/09/2025 10:29              Jeanne            Juridico     12/09/2025
# 1  03/09/2025 15:57             Katiana             Locação     03/09/2025
# 2  27/08/2025 11:42              Mateus       Contabilidade     27/08/2025
# 3  25/08/2025 14:36                Cleo                  RH     25/08/2025
# 4  20/08/2025 11:49              Daiana            Jurídico     20/08/2025
#
#   Data de fim
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

# Ler o arquivo CSV com separador ';'
df = pd.read_csv('/issues.txt', sep=';')

# Converter a coluna 'Data de início' para datetime
df['Data de início'] = pd.to_datetime(df['Data de início'], format='%d/%m/%Y', errors='coerce')

# Remover linhas com datas inválidas
df_clean = df.dropna(subset=['Data de início'])

print(f"Total de registros com data válida: {len(df_clean)}")
print(f"Período analisado: {df_clean['Data de início'].min().strftime('%d/%m/%Y')} a {df_clean['Data de início'].max().strftime('%d/%m/%Y')}")

# Criar coluna com ano-mês para agrupamento
df_clean['Ano_Mes'] = df_clean['Data de início'].dt.to_period('M')

# Contar solicitações por mês
solicitacoes_por_mes = df_clean.groupby('Ano_Mes').size().reset_index(name='Quantidade')

# Converter período para string para melhor visualização
solicitacoes_por_mes['Mes_Str'] = solicitacoes_por_mes['Ano_Mes'].astype(str)

print("\nSolicitações por mês:")
print(solicitacoes_por_mes)

# Criar o gráfico de linha (curva de crescimento)
plt.figure(figsize=(15, 8))

# Plotar a linha principal
plt.plot(solicitacoes_por_mes['Mes_Str'],
         solicitacoes_por_mes['Quantidade'],
         marker='o',
         linewidth=2.5,
         markersize=8,
         color='#2E86AB',
         markerfacecolor='#A23B72',
         markeredgecolor='white',
         markeredgewidth=2)

# Adicionar valores nos pontos
for i, (mes, qtd) in enumerate(zip(solicitacoes_por_mes['Mes_Str'], solicitacoes_por_mes['Quantidade'])):
    plt.annotate(f'{qtd}',
                (i, qtd),
                textcoords="offset points",
                xytext=(0,10),
                ha='center',
                fontsize=10,
                fontweight='bold',
                color='#2E86AB')

# Adicionar linha de tendência
z = np.polyfit(range(len(solicitacoes_por_mes)), solicitacoes_por_mes['Quantidade'], 1)
p = np.poly1d(z)
plt.plot(solicitacoes_por_mes['Mes_Str'], p(range(len(solicitacoes_por_mes))),
         "--", alpha=0.7, color='red', linewidth=2, label='Linha de Tendência')

# Personalizar o gráfico
plt.title('Evolução Temporal das Solicitações de TI\n(Curva de Crescimento por Mês)',
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Período (Ano-Mês)', fontsize=12, fontweight='bold')
plt.ylabel('Número de Solicitações', fontsize=12, fontweight='bold')

# Rotacionar labels do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar grid
plt.grid(True, alpha=0.3, linestyle='-', linewidth=0.5)

# Adicionar área sombreada sob a curva
plt.fill_between(solicitacoes_por_mes['Mes_Str'],
                 solicitacoes_por_mes['Quantidade'],
                 alpha=0.2, color='#2E86AB')

# Adicionar legenda
plt.legend(fontsize=10)

# Ajustar layout
plt.tight_layout()
plt.show()

# Análise estatística
print(f"\nEstatísticas da evolução temporal:")
print(f"Média de solicitações por mês: {solicitacoes_por_mes['Quantidade'].mean():.1f}")
print(f"Mediana de solicitações por mês: {solicitacoes_por_mes['Quantidade'].median():.1f}")
print(f"Desvio padrão: {solicitacoes_por_mes['Quantidade'].std():.1f}")

# Identificar picos e vales
max_mes = solicitacoes_por_mes.loc[solicitacoes_por_mes['Quantidade'].idxmax()]
min_mes = solicitacoes_por_mes.loc[solicitacoes_por_mes['Quantidade'].idxmin()]

print(f"\nMês com MAIS solicitações: {max_mes['Mes_Str']} ({max_mes['Quantidade']} solicitações)")
print(f"Mês com MENOS solicitações: {min_mes['Mes_Str']} ({min_mes['Quantidade']} solicitações)")

# Análise de tendência
if z[0] > 0:
    print(f"\nTendência: CRESCENTE (coeficiente: +{z[0]:.2f} solicitações/mês)")
elif z[0] < 0:
    print(f"\nTendência: DECRESCENTE (coeficiente: {z[0]:.2f} solicitações/mês)")
else:
    print(f"\nTendência: ESTÁVEL")

# Mostrar os 5 meses com mais solicitações
top_5_meses = solicitacoes_por_mes.nlargest(5, 'Quantidade')
print(f"\nTop 5 meses com mais solicitações:")
for idx, row in top_5_meses.iterrows():
    print(f"{row['Mes_Str']}: {row['Quantidade']} solicitações")
# Out:
# Total de registros com data válida: 77
# Período analisado: 08/10/2024 a 12/09/2025
#
# Solicitações por mês:
#     Ano_Mes  Quantidade  Mes_Str
# 0   2024-10           8  2024-10
# 1   2024-12           1  2024-12
# 2   2025-01           9  2025-01
# 3   2025-02           5  2025-02
# 4   2025-03          13  2025-03
# 5   2025-04          10  2025-04
# 6   2025-05           9  2025-05
# 7   2025-06           9  2025-06
# 8   2025-07           7  2025-07
# 9   2025-08           4  2025-08
# 10  2025-09           2  2025-09
# Estatísticas da evolução temporal:
# Média de solicitações por mês: 7.0
# Mediana de solicitações por mês: 8.0
# Desvio padrão: 3.6
#
# Mês com MAIS solicitações: 2025-03 (13 solicitações)
# Mês com MENOS solicitações: 2024-12 (1 solicitações)
#
# Tendência: DECRESCENTE (coeficiente: -0.18 solicitações/mês)
#
# Top 5 meses com mais solicitações:
# 2025-03: 13 solicitações
# 2025-04: 10 solicitações
# 2025-01: 9 solicitações
# 2025-05: 9 solicitações
# ...
